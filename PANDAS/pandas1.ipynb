# %% [markdown]
# #Core Ideas
# ##●​ A Pandas Series behaves like a dictionary-backed vector: values are like a NumPy array; labels (index) are like dictionary keys.​
# ##●​ Operations respect the index: this makes Pandas ideal for labelled time series or named features.​
# ##●​ Method chaining encourages writing "pipelines", stepwise transformations applied in sequence.​
# ##●​ Series enables clean, readable, high-level operations without the verbosity of loops.​

# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
import pandas as pd
df = pd.DataFrame({"col1":[1, 2], "col2": [3, 4]})
df.head()
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
import pandas as pd

# Creating a Series from a dictionary with custom index
student_scores = pd.Series(
    {"Alice": 85, "Bob": 92, "Charlie": 78, "Diana": 95},
    index=["Bob", "Alice", "Diana", "Charlie"],  # Reorders the data!
)

print(student_scores)
# Out:
# Bob        92
# Alice      85
# Diana      95
# Charlie    78
# dtype: int64

# %%
import pandas as pd

# Creating a DataFrame from a dictionary with custom index  
student_scores = pd.DataFrame(
    {"Alice": 85, "Bob": 92, "Charlie": 78, "Diana": 95},
    index=["Bob", "Alice", "Diana", "Charlie"],  # Reorders the data!
)

print(student_scores)
# Out:
#          Alice  Bob  Charlie  Diana
# Bob         85   92       78     95
# Alice       85   92       78     95
# Diana       85   92       78     95
# Charlie     85   92       78     95

# %%
pd.Series([10, 20, 30])
# Key Point: If you don't specify an index, Pandas automatically creates a numeric index starting from 0.
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# From a List with Custom Index
pd.Series([10, 20, 30], index=["a", "b", "c"])
# Key Point: Custom labels make data more meaningful and self-descriptive.
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# From a Dictionary
pd.Series({"x": 10, "y": 20, "z": 30})
# Key Point: The dictionary keys become the index, and values become the Series data.
# Out:
# x    10
# y    20
# z    30
# dtype: int64
